# %% [markdown]
# # IDESCAT

# %% [markdown]
# ### Altitud

# %% [markdown]
# **Datos disponibles en:** https://www.idescat.cat/indicadors/?id=aec&n=15903&lang=es

# %%
Altitud = spark.read.format("csv") \
.option("inferSchema", "true") \
.option("header", "true") \
.option("sep", ";") \
.load("/mnt/IncendiosForestalesCAT/raw/idescat/cartografia/Altitud.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Altitud.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Superficie y Pendientes

# %% [markdown]
# **Datos disponibles en:** https://www.idescat.cat/indicadors/?id=aec&n=15181&lang=es
#
#
# + Unidades: Kilómetros cuadrados.
# + Fuente: Institut Cartogràfic i Geològic de Catalunya.

# %%
#CSV
Pendiente = spark.read.format("csv") \
.option("inferSchema", "true") \
.option("header", "true") \
.option("sep", "\t") \
.load("/mnt/IncendiosForestalesCAT/raw/idescat/cartografia/pendienteCAT.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Pendiente.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
