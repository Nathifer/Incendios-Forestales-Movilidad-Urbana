# %%
from functools import reduce
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls(f"/mnt/IncendiosForestalesCAT/raw/proteccion_civil_cat"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/IncendiosForestalesCAT/raw/proteccion_civil_cat/incendios_riesgo.csv</td><td>incendios_riesgo.csv</td><td>57402</td><td>1669546029000</td></tr></tbody></table></div>

# %% [markdown]
# #PROTECCION CIVIL CATALUÑA

# %%
#CSV
Riesgo_incendio_PC_CAT = spark.read.format("csv") \
.option("inferSchema", "true") \
.option("header", "true") \
.option("sep", ",") \
.load("/mnt/IncendiosForestalesCAT/raw/proteccion_civil_cat/incendios_riesgo.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(Riesgo_incendio_PC_CAT)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MUNICIPI</th><th>NOM_MUNI</th><th>HA_FOR</th><th>PER_FOR</th><th>PER_PPP</th><th>PERILL</th><th>VULNER</th></tr></thead><tbody><tr><td>250450</td><td>Bausen</td><td>1755.9</td><td>99.07074</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>250637</td><td>Canejan</td><td>4467.51</td><td>92.44278</td><td>0.0</td><td>Baix</td><td>Mitja</td></tr><tr><td>251214</td><td>Les</td><td>2281.05</td><td>97.2638</td><td>0.0</td><td>Baix</td><td>Mitja</td></tr><tr><td>250254</td><td>Naut Aran</td><td>20748.6</td><td>81.11722</td><td>0.0</td><td>Baix</td><td>Molt Alta</td></tr><tr><td>250595</td><td>Bossost</td><td>2783.88</td><td>98.84007</td><td>0.0</td><td>Baix</td><td>Mitja</td></tr><tr><td>252430</td><td>Vielha e Mijaran</td><td>17999.37</td><td>85.01007</td><td>0.0</td><td>Baix</td><td>Molt Alta</td></tr><tr><td>252477</td><td>Vilamos</td><td>1525.23</td><td>98.70122</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>250241</td><td>Alt Aneu</td><td>17755.56</td><td>81.53984</td><td>0.0</td><td>Baix</td><td>Molt Alta</td></tr><tr><td>250313</td><td>Arres</td><td>1130.04</td><td>97.71206</td><td>0.0</td><td>Exclos</td><td>Moderada</td></tr><tr><td>250576</td><td>Es Bordes</td><td>2107.44</td><td>98.33697</td><td>0.0</td><td>Baix</td><td>Mitja</td></tr><tr><td>251235</td><td>Lladorre</td><td>11021.22</td><td>74.97673</td><td>0.0</td><td>Moderat</td><td>Molt Alta</td></tr><tr><td>259031</td><td>la Guingueta d'Aneu</td><td>9891.18</td><td>91.24435</td><td>0.0</td><td>Moderat</td><td>Alta</td></tr><tr><td>250175</td><td>Alins</td><td>15251.04</td><td>83.25194</td><td>0.0</td><td>Moderat</td><td>Molt Alta</td></tr><tr><td>259010</td><td>Vall de Cardos</td><td>5464.8</td><td>97.26405</td><td>0.0</td><td>Moderat</td><td>Mitja</td></tr><tr><td>250864</td><td>Esterri d'Aneu</td><td>651.6</td><td>76.74369</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>250432</td><td>la Vall de Boí</td><td>16393.23</td><td>74.67949</td><td>0.0</td><td>Baix</td><td>Molt Alta</td></tr><tr><td>252458</td><td>Vilaller</td><td>4646.97</td><td>78.46841</td><td>0.0</td><td>Baix</td><td>Alta</td></tr><tr><td>250827</td><td>Espot</td><td>7341.93</td><td>75.45322</td><td>0.0</td><td>Baix</td><td>Molt Alta</td></tr><tr><td>250870</td><td>Esterri de Cardos</td><td>1616.76</td><td>97.69946</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>252271</td><td>la Torre de Cabdella</td><td>13940.1</td><td>84.35402</td><td>0.0</td><td>Moderat</td><td>Molt Alta</td></tr><tr><td>252398</td><td>les Valls de Valira</td><td>16161.03</td><td>94.36839</td><td>0.0</td><td>Moderat</td><td>Alta</td></tr><tr><td>251266</td><td>Llavorsí</td><td>6769.53</td><td>98.79944</td><td>0.0</td><td>Moderat</td><td>Mitja</td></tr><tr><td>252094</td><td>Sort</td><td>9878.4</td><td>94.03137</td><td>0.0</td><td>Moderat</td><td>Molt Alta</td></tr><tr><td>252213</td><td>Tirvia</td><td>833.76</td><td>98.14599</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>251832</td><td>Rialp</td><td>6263.28</td><td>98.94785</td><td>0.0</td><td>Moderat</td><td>Mitja</td></tr><tr><td>250899</td><td>Farrera</td><td>6092.46</td><td>98.51272</td><td>0.0</td><td>Moderat</td><td>Mitja</td></tr><tr><td>251272</td><td>Lles de Cerdanya</td><td>9235.62</td><td>89.84634</td><td>0.0</td><td>Moderat</td><td>Alta</td></tr><tr><td>252017</td><td>Sarroca de Bellera</td><td>8005.95</td><td>91.49866</td><td>0.0</td><td>Moderat</td><td>Mitja</td></tr><tr><td>170998</td><td>Meranges</td><td>3361.95</td><td>90.06631</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>251734</td><td>el Pont de Suert</td><td>14073.93</td><td>95.01407</td><td>0.0</td><td>Moderat</td><td>Molt Alta</td></tr><tr><td>170947</td><td>Llivia</td><td>744.48</td><td>57.55636</td><td>0.0</td><td>Moderat</td><td>Moderada</td></tr><tr><td>170828</td><td>Guils de Cerdanya</td><td>1696.14</td><td ...

# %%
Riesgo_incendio_PC_CAT.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 947</div>

# %% [markdown]
# ##JOIN ALTITUD y PENDIENTE

# %%
#CSV
alt_pend = spark.read.format("parquet") \
.load("/mnt/IncendiosForestalesCAT/prep/idescat/cartografia/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
alt_pend_risc = alt_pend.alias("df1").join(Riesgo_incendio_PC_CAT.alias("df2"), F.col("df1.cod_municipio")== F.col("df2.MUNICIPI"), "left").select(["df1.*","df2.MUNICIPI","PERILL", "NOM_MUNI"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
alt_pend_risc.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: 947</div>

# %%
display(alt_pend_risc)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>altitud</th><th>cod_idescat</th><th>municipio</th><th>comarca</th><th>cod_municipio</th><th>superficie_total</th><th>superficie_menos_20</th><th>porcentaje_pendiente</th><th>porcentaje_pendiente_total</th><th>MUNICIPI</th><th>PERILL</th><th>NOM_MUNI</th></tr></thead><tbody><tr><td>956</td><td>250019</td><td>Abella de la Conca</td><td>Pallars Jussà</td><td>25001</td><td>1343,1</td><td>223,2</td><td>16,6</td><td>1,6</td><td>null</td><td>null</td><td>null</td></tr><tr><td>105</td><td>80018</td><td>Abrera</td><td>Baix Llobregat</td><td>80018</td><td>486</td><td>249,8</td><td>51,4</td><td>1,7</td><td>80018</td><td>Molt Alt</td><td>Abrera</td></tr><tr><td>642</td><td>250024</td><td>Àger</td><td>Noguera</td><td>25002</td><td>1784,1</td><td>973,3</td><td>54,6</td><td>6,8</td><td>null</td><td>null</td><td>null</td></tr><tr><td>337</td><td>250030</td><td>Agramunt</td><td>Urgell</td><td>25003</td><td>579,7</td><td>562,7</td><td>97,1</td><td>3,9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>480</td><td>80023</td><td>Aguilar de Segarra</td><td>Bages</td><td>80023</td><td>1092,3</td><td>:</td><td>:</td><td>:</td><td>80023</td><td>Alt</td><td>Aguilar de Segarra</td></tr><tr><td>166</td><td>170010</td><td>Agullana</td><td>Alt Empordà</td><td>17001</td><td>1357,5</td><td>734,3</td><td>54,1</td><td>5,1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>404</td><td>80142</td><td>Aiguafreda</td><td>Vallès Oriental</td><td>80142</td><td>735</td><td>:</td><td>:</td><td>:</td><td>80142</td><td>Alt</td><td>Aiguafreda</td></tr><tr><td>314</td><td>430017</td><td>Aiguamúrcia</td><td>Alt Camp</td><td>43001</td><td>538</td><td>335,5</td><td>62,4</td><td>2,3</td><td>null</td><td>null</td><td>null</td></tr><tr><td>169</td><td>170025</td><td>Aiguaviva</td><td>Gironès</td><td>17002</td><td>575,6</td><td>414,9</td><td>72,1</td><td>2,9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>110</td><td>250387</td><td>Aitona</td><td>Segrià</td><td>25038</td><td>1396,7</td><td>1282,4</td><td>91,8</td><td>9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>212</td><td>250045</td><td>Alamús, els</td><td>Segrià</td><td>25004</td><td>1396,7</td><td>1282,4</td><td>91,8</td><td>9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>768</td><td>250058</td><td>Alàs i Cerc</td><td>Alt Urgell</td><td>25005</td><td>1447,5</td><td>125,9</td><td>8,7</td><td>0,9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>372</td><td>250061</td><td>Albagés, l'</td><td>Garrigues</td><td>25006</td><td>797,7</td><td>583</td><td>73,1</td><td>4,1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>239</td><td>170031</td><td>Albanyà</td><td>Alt Empordà</td><td>17003</td><td>1357,5</td><td>734,3</td><td>54,1</td><td>5,1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>147</td><td>250077</td><td>Albatàrrec</td><td>Segrià</td><td>25007</td><td>1396,7</td><td>1282,4</td><td>91,8</td><td>9</td><td>null</td><td>null</td><td>null</td></tr><tr><td>237</td><td>250083</td><td>Albesa</td><td>Noguera</td><td>25008</td><td>1784,1</td><td>973,3</td><td>54,6</td><td>6,8</td><td>null</td><td>null</td><td>null</td></tr><tr><td>526</td><td>250096</td><td>Albi, l'</td><td>Garrigues</td><td>25009</td><td>797,7</td><td>583</td><td>73,1</td><td>4,1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>198</td><td>430022</td><td>Albinyana</td><td>Baix Penedès</td><td>43002</td><td>296,5</td><td>163,2</td><td>55</td><td>1,1</td><td>null</td><td>null</td><td>null</td></tr><tr><td>823</td><td>430038</td><td>Albiol, l'</td><td>Baix Camp</td><td>43003</td><td>697,2</td><td>356</td><td>51,1</td><td>2,5</td><td>null</td><td>null</td><td>null</td></tr><tr><td>25</td><td>170046</td><td>Albons</td><td>Baix Empordà</td><td>17004</td><td>701,7</td><td>515,5</td><td>73,5</td><td>3,6</td><td>null</td><td>null</td><td>null</td></tr><tr><td>72</td><td>430043</td><td>Alcana ...
