# %%
from functools import reduce

def load_table(file_location, 
               table_name, 
               rename_columns=None, 
               file_type="csv", 
               delimiter=";"):
  
  # The applied options are for CSV files. For other file types, these will be ignored.
  df = spark.read.format(file_type) \
    .option("inferSchema", "true") \
    .option("header", "true") \
    .option("sep", delimiter) \
    .load(file_location)
  df.columns
  if rename_columns is not None:
    df = reduce(lambda dfl, x: dfl.withColumnRenamed(x,rename_columns[x]),rename_columns, df)
    df.columns

  # Create a view or table
  df.createOrReplaceTempView(table_name)

  # Since this table is registered as a temp view, it will only be available to this notebook. If you'd like other users to be able to query  this table, you can also create a table from the DataFrame.
  # Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
  # To do so, choose your table name and uncomment the bottom line.

  df.write.format("parquet").saveAsTable(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # INE

# %% [markdown]
# ### Codigo de Municipios - CODIGO MITMA

# %%
# TABLA DEL INE CODIGO DE MUNCIPIOS - CODIGO MITMA
file_location = "/mnt/IncendiosForestalesCAT/raw/ine/"
file_type = "csv"
table_name = "nacional_moviles"

load_table(file_location, table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3453004520395224&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> table_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;nacional_moviles&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>
# <span class="ansi-green-fg">----&gt; 6</span><span class="ansi-red-fg"> </span>load_table<span class="ansi-blue-fg">(</span>file_location<span class="ansi-blue-fg">,</span> table_name<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">&lt;command-3873852187390091&gt;</span> in <span class="ansi-cyan-fg">load_table</span><span class="ansi-blue-fg">(file_location, table_name, rename_columns, file_type, delimiter)</span>
# <span class="ansi-green-intense-fg ansi-bold">     25</span>   <span class="ansi-red-fg"># To do so, choose your table name and uncomment the bottom line.</span>
# <span class="ansi-green-intense-fg ansi-bold">     26</span>
# <span class="ansi-green-fg">---&gt; 27</span><span class="ansi-red-fg">   </span>df<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>table_name<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    804</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    805</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 806</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    807</span>
# <span class="ansi-green-intense-fg ansi-bold">    808</span>     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Table `nacional_moviles` already exists.</div>

# %%
municipios_catalunya_INE = spark.sql("""
SELECT * FROM nacional_moviles WHERE NPRO in ('Barcelona', 'Tarragona', 'Girona', 'Lleida');
""")
display(municipios_catalunya_INE)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CUMUN</th><th>CPRO</th><th>NPRO</th><th>NMUN</th><th>AREA_GEO</th><th>ID_AREA_GEO</th><th>POB_AREA_GEO</th><th>COD_LITERAL_SCD</th><th>ID_GRUPO</th><th>POB_GRUPO</th><th>ID_COMPLETO_GRUPO</th><th>LITERAL_GRUPO</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th></tr></thead><tbody><tr><td>08038</td><td>8</td><td>Barcelona</td><td>Callús</td><td>MUNICIPIO</td><td>08038</td><td>2140</td><td>null</td><td>001B</td><td>14529</td><td>08038 Callús</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08084</td><td>8</td><td>Barcelona</td><td>Fonollosa</td><td>MUNICIPIO</td><td>08084</td><td>1453</td><td>null</td><td>001B</td><td>14529</td><td>08084 Fonollosa</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08218</td><td>8</td><td>Barcelona</td><td>Sant Joan de Vilatorrada</td><td>MUNICIPIO</td><td>08218</td><td>10936</td><td>null</td><td>001B</td><td>14529</td><td>08218 Sant Joan de Vilatorrada</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08021</td><td>8</td><td>Barcelona</td><td>Bellprat</td><td>MUNICIPIO</td><td>08021</td><td>64</td><td>null</td><td>002B</td><td>6522</td><td>08021 Bellprat</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08063</td><td>8</td><td>Barcelona</td><td>Castellolí</td><td>MUNICIPIO</td><td>08063</td><td>619</td><td>null</td><td>002B</td><td>6522</td><td>08063 Castellolí</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08103</td><td>8</td><td>Barcelona</td><td>Jorba</td><td>MUNICIPIO</td><td>08103</td><td>835</td><td>null</td><td>002B</td><td>6522</td><td>08103 Jorba</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08143</td><td>8</td><td>Barcelona</td><td>Òdena</td><td>MUNICIPIO</td><td>08143</td><td>3643</td><td>null</td><td>002B</td><td>6522</td><td>08143 Òdena</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08226</td><td>8</td><td>Barcelona</td><td>Sant Martí de Tous</td><td>MUNICIPIO</td><td>08226</td><td>1235</td><td>null</td><td>002B</td><td>6522</td><td>08226 Sant Martí de Tous</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08257</td><td>8</td><td>Barcelona</td><td>Santa Maria de Miralles</td><td>MUNICIPIO</td><td>08257</td><td>126</td><td>null</td><td>002B</td><td>6522</td><td>08257 Santa Maria de Miralles</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08165</td><td>8</td><td>Barcelona</td><td>Pobla de Claramunt, La</td><td>MUNICIPIO</td><td>08165</td><td>2193</td><td>null</td><td>003B</td><td>5907</td><td>08165 Pobla de Claramunt, La</td><td>Torre de Claramunt, La y Pobla de Claramunt, La</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08286</td><td>8</td><td>Barcelona</td><td>Torre de Claramunt, La</td><td>MUNICIPIO</td><td>08286</td><td>3714</td><td>null</td><td>003B</td><td>5907</td><td>08286 Torre de Claramunt, La</td><td>Torre de Claramunt, La y Pobla de Claramunt, La</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08044</td><td>8</td><td>Barcelona</td><td>Capellades</td><td>MUNICIPIO</td><td>08044</td><td>5293</td><td>null</td><td>004B</td><td>6666</td><td>08044 Capellades</td><td>Capellades y Vallbona d'Anoia</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>08292</td><td>8</td><td>Barcelona</td><td>Vallbona d'Anoia</td><td>MUNICIPIO</td><td>08292</td><td>1373</td><td>null</td><td>004B</td><td>6666</td><td>08292 Vallbona d'Anoia</td><td>Capellades y Vallbona d'Anoia</td><td>null</td ...

# %%
municipios_catalunya_INE = spark.sql("""
SELECT * FROM nacional_moviles WHERE NPRO in ('Barcelona', 'Tarragona', 'Girona', 'Lleida') and CONTAINS(NMUN, 'Tàrrega') ;
""")
display(municipios_catalunya_INE)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CUMUN</th><th>CPRO</th><th>NPRO</th><th>NMUN</th><th>AREA_GEO</th><th>ID_AREA_GEO</th><th>POB_AREA_GEO</th><th>COD_LITERAL_SCD</th><th>ID_GRUPO</th><th>POB_GRUPO</th><th>ID_COMPLETO_GRUPO</th><th>LITERAL_GRUPO</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th></tr></thead><tbody><tr><td>25217</td><td>25</td><td>Lleida</td><td>Tàrrega</td><td>MUNICIPIO</td><td>25217</td><td>17098</td><td>null</td><td>44LL</td><td>17098</td><td>25217 Tàrrega</td><td>Tàrrega</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### CCAA_PROVINCIAS

# %% [markdown]
# **Datos disponibles en:** https://www.ine.es/daco/daco42/codmun/cod_ccaa_provincia.htm

# %%
# TABLA DEL INE - CCAA_PROVINCIAS
file_location = "/mnt/IncendiosForestalesCAT/raw/ine/provincias-espanolas_nathalia.csv"
permanent_table_name = "cca_provincias"
dbutils.fs.rm(f"/user/hive/warehouse/{permanent_table_name}/", True)

load_table(file_location, permanent_table_name,rename_columns={"CODAUTO":"cod_autonoma","Comunidad Autónoma":"comunidad_autonoma","CPRO":"cod_provincia","Provincia":"provincia"}, delimiter=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql SELECT * FROM cca_provincias where comunidad_autonoma = "Cataluña" ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cod_autonoma</th><th>comunidad_autonoma</th><th>cod_provincia</th><th>provincia</th></tr></thead><tbody><tr><td>9</td><td>Cataluña</td><td>8</td><td>Barcelona</td></tr><tr><td>9</td><td>Cataluña</td><td>17</td><td>Girona</td></tr><tr><td>9</td><td>Cataluña</td><td>25</td><td>Lleida</td></tr><tr><td>9</td><td>Cataluña</td><td>43</td><td>Tarragona</td></tr></tbody></table></div>
