# %% [markdown]
# # AEMET

# %% [markdown]
# ### Estaciones

# %%
# !pip install tqdm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.3 MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.64.1
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.3.1 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# </div>

# %%
import requests
import datetime
import pandas as pd
from tqdm import tqdm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Cargamos la api key 
api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJuYXRoYWxpYWZlcm5hbmRlenI5NUBnbWFpbC5jb20iLCJqdGkiOiI0YzVlN2Q4NS1hYTc2LTQ2ZGUtYTM1ZC02NDdjZTQ3Yjc5MGYiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTY2MDA0MTEzNCwidXNlcklkIjoiNGM1ZTdkODUtYWE3Ni00NmRlLWEzNWQtNjQ3Y2U0N2I3OTBmIiwicm9sZSI6IiJ9.pThNL0YZyUC2utBPxEbhKHM16LZmXkVMQWkL9uJGWW0"
querystring = {"api_key": api_key}

# Obtenemos información de todas las estaciones disponibles
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones"

# Realizamos la request
r = requests.get(url, params=querystring, verify=False)

# Obtenemos el link del que descargaremos los datos
data_url = r.json()['datos']
r_data = requests.get(data_url, params=querystring, verify=False)

#Creamos el DataFrame 
spark.createDataFrame(r_data.json()).coalesce(1).write.mode("overwrite").parquet(f"/mnt/IncendiosForestalesCAT/raw/aemet/estaciones/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# </div>

# %%
display(spark.read.parquet(f"/mnt/IncendiosForestalesCAT/raw/aemet/estaciones/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>altitud</th><th>indicativo</th><th>indsinop</th><th>latitud</th><th>longitud</th><th>nombre</th><th>provincia</th></tr></thead><tbody><tr><td>74</td><td>0252D</td><td>08186</td><td>413515N</td><td>023224E</td><td>ARENYS DE MAR</td><td>BARCELONA</td></tr><tr><td>4</td><td>0076</td><td>08181</td><td>411734N</td><td>020412E</td><td>BARCELONA AEROPUERTO</td><td>BARCELONA</td></tr><tr><td>408</td><td>0200E</td><td></td><td>412506N</td><td>020727E</td><td>BARCELONA, FABRA</td><td>BARCELONA</td></tr><tr><td>6</td><td>0201D</td><td>08180</td><td>412326N</td><td>021200E</td><td>BARCELONA</td><td>BARCELONA</td></tr><tr><td>291</td><td>0149X</td><td>08174</td><td>414312N</td><td>015025E</td><td>MANRESA</td><td>BARCELONA</td></tr><tr><td>146</td><td>0229I</td><td>08192</td><td>413125N</td><td>020611E</td><td>SABADELL AEROPUERTO</td><td>BARCELONA</td></tr><tr><td>40</td><td>0255B</td><td>08188</td><td>413903N</td><td>024149E</td><td>SANTA SUSANNA</td><td>BARCELONA</td></tr><tr><td>143</td><td>0367</td><td>08184</td><td>415442N</td><td>024548E</td><td>GIRONA AEROPUERTO</td><td>GIRONA</td></tr><tr><td>95</td><td>0370B</td><td></td><td>415848N</td><td>024931E</td><td>GIRONA, ANTIC INSTITUT</td><td>GIRONA</td></tr><tr><td>157</td><td>0372C</td><td>08120</td><td>420616N</td><td>024549E</td><td>PORQUERES</td><td>GIRONA</td></tr><tr><td>675</td><td>0324A</td><td>08118</td><td>421129N</td><td>021146E</td><td>RIPOLL</td><td>GIRONA</td></tr><tr><td>71</td><td>0016A</td><td>08175</td><td>410842N</td><td>010949E</td><td>REUS AEROPUERTO</td><td>TARRAGONA</td></tr><tr><td>32</td><td>0002I</td><td>08169</td><td>405729N</td><td>005217E</td><td>VANDELLÒS  </td><td>TARRAGONA</td></tr><tr><td>98</td><td>1387E</td><td>08002</td><td>431825N</td><td>082219W</td><td>A CORUÑA AEROPUERTO</td><td>A CORUÑA</td></tr><tr><td>58</td><td>1387</td><td>08001</td><td>432157N</td><td>082517W</td><td>A CORUÑA</td><td>A CORUÑA</td></tr><tr><td>50</td><td>1393</td><td>08006</td><td>430938N</td><td>091239W</td><td>CABO VILÁN</td><td>A CORUÑA</td></tr><tr><td>90</td><td>1351</td><td>08004</td><td>434710N</td><td>074106W</td><td>ESTACA DE BARES</td><td>A CORUÑA</td></tr><tr><td>230</td><td>1400</td><td>08040</td><td>425529N</td><td>091729W</td><td>FISTERRA</td><td>A CORUÑA</td></tr><tr><td>685</td><td>1437O</td><td>08043</td><td>424314N</td><td>085524W</td><td>MONTE IROITE</td><td>A CORUÑA</td></tr><tr><td>100</td><td>1473A</td><td>08039</td><td>424418N</td><td>083738W</td><td>PADRÓN</td><td>A CORUÑA</td></tr><tr><td>370</td><td>1428</td><td>08042</td><td>425317N</td><td>082438W</td><td>SANTIAGO DE COMPOSTELA AEROPUERTO</td><td>A CORUÑA</td></tr><tr><td>240</td><td>1475X</td><td>08041</td><td>425234N</td><td>083321W</td><td>SANTIAGO DE COMPOSTELA</td><td>A CORUÑA</td></tr><tr><td>127</td><td>1212E</td><td>08011</td><td>433401N</td><td>060239W</td><td>ASTURIAS AEROPUERTO</td><td>ASTURIAS</td></tr><tr><td>60</td><td>1283U</td><td>08010</td><td>433409N</td><td>062812W</td><td>CABO BUSTO</td><td>ASTURIAS</td></tr><tr><td>100</td><td>1210X</td><td>08012</td><td>433921N</td><td>055055W</td><td>CABO PEÑAS</td><td>ASTURIAS</td></tr><tr><td>40</td><td>1331A</td><td>08009</td><td>433129N</td><td>070153W</td><td>CASTROPOL</td><td>ASTURIAS</td></tr><tr><td>26</td><td>1207U</td><td>08014</td><td>433123N</td><td>053716W</td><td>GIJÓN, CAMPUS</td><td>ASTURIAS</td></tr><tr><td>22</td><td>1208A</td><td></td><td>433230N</td><td>053943W</td><td>GIJÓN. LA MERCED</td><td>ASTURIAS</td></tr><tr><td>5</td><td>1208H</td><td>08014</td><td>433336N</td><td>054203W</td><td>GIJÓN, PUERTO</td><td>ASTURIAS</td></tr><tr><td>3</td><td>1208</td><td></td><td>433220N</td><td>053815W</td><td>GIJÓN</td><td>ASTURIAS</td></tr><tr><td>10</td><td>1183X</td><td>08016</td><td>432513N</td><td>044453W</td><td>LLANES</td><td>ASTURIAS</td></tr><tr><td>336</td><td>1249I</td><td>08015</td><td>432112N</td><td>0552 ...

# %% [markdown]
# + **Altitud de la estacion:** altitud en la que se encuentra ubicada la estacion
# + **Indicativo:** Codigo de la estacion
# + **Indsinop:** codigo sinoptico usado para reportar observaciones meteorológicas hechas por estaciones meteorológicas en superficie tanto así como por estaciones meteorológicas automáticas.
# + **Latitud:** Latitud en la que se encuentra ubicada la estacion
# + **Longitud:** Longitud en la que se encuentra ubicada la estacion
# + **Nombre:** Nombre de la estacion
# + **Provincia:** Provincia en la que se encuentra ubicada la estacion

# %% [markdown]
# ### Valores Climatologicos

# %%
# CARGAR VALORES CLIMATOLOGICOS DIARIOS AEMET
from dateutil.relativedelta import relativedelta

fechaini="2015-01-01"
fechafin="2022-02-01"
start = datetime.datetime.strptime(fechaini, '%Y-%m-%d').date()
end = datetime.datetime.strptime(fechafin, '%Y-%m-%d').date()

dates = pd.date_range(start, end, freq='m')

print(f'Downloading files for the period {start} - {end}')

s = requests.Session()

for d in tqdm(dates):
    vcm = ("https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos"
       f"/fechaini/{start}T00:00:00UTC/fechafin/{d:%Y-%m-%d}T00:00:00UTC/todasestaciones")
    r = requests.get(vcm, params=querystring, verify=False)

    if r.status_code == requests.codes.OK:
        data_url = r.json()['datos']
        r_data = requests.get(data_url, params=querystring, verify=False)
        raw_data = r_data.json()
        spark.createDataFrame(raw_data).coalesce(1).write.mode("append").parquet(f"/mnt/IncendiosForestalesCAT/raw/aemet/valores_clima_diarios/")
    start= start + relativedelta(months=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Downloading files for the period 2015-01-01 - 2022-02-01
#   0%|          | 0/85 [00:00&lt;?, ?it/s]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   1%|          | 1/85 [00:07&lt;09:52,  7.05s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   2%|▏         | 2/85 [00:12&lt;08:49,  6.38s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   4%|▎         | 3/85 [00:19&lt;08:53,  6.50s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   5%|▍         | 4/85 [00:25&lt;08:15,  6.12s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   6%|▌         | 5/85 [00:31&lt;08:06,  6.09s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   7%|▋         | 6/85 [00:37&lt;07:53,  6.00s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   8%|▊         | 7/85 [00:42&lt;07:37,  5.86s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#   9%|▉         | 8/85 [00:49&lt;07:48,  6.09s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#  11%|█         | 9/85 [00:55&lt;07:42,  6.08s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#  12%|█▏        | 10/85 [01:01&lt;07:50,  6.27s/it]/databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /databricks/python/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host &#39;opendata.aemet.es&#39;. Adding certificate verification is str

# %%
display(spark.read.parquet(f"/mnt/IncendiosForestalesCAT/raw/aemet/valores_clima_diarios/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>altitud</th><th>dir</th><th>fecha</th><th>horaPresMax</th><th>horaPresMin</th><th>horaracha</th><th>horatmax</th><th>horatmin</th><th>indicativo</th><th>nombre</th><th>prec</th><th>presMax</th><th>presMin</th><th>provincia</th><th>racha</th><th>sol</th><th>tmax</th><th>tmed</th><th>tmin</th><th>velmedia</th></tr></thead><tbody><tr><td>273</td><td>20</td><td>2016-01-01</td><td>00</td><td>15</td><td>17:30</td><td>14:00</td><td>03:20</td><td>4358X</td><td>DON BENITO</td><td>9,2</td><td>992,5</td><td>985,6</td><td>BADAJOZ</td><td>13,1</td><td>3,6</td><td>19,7</td><td>14,1</td><td>8,5</td><td>4,2</td></tr><tr><td>632</td><td>99</td><td>2016-01-01</td><td>Varias</td><td>04</td><td>Varias</td><td>14:08</td><td>00:43</td><td>C447A</td><td>TENERIFE NORTE AEROPUERTO</td><td>0,0</td><td>955,6</td><td>953,2</td><td>STA. CRUZ DE TENERIFE</td><td>7,2</td><td>9,1</td><td>19,7</td><td>15,2</td><td>10,8</td><td>2,8</td></tr><tr><td>807</td><td>99</td><td>2016-01-01</td><td>00</td><td>Varias</td><td>Varias</td><td>14:10</td><td>05:00</td><td>9698U</td><td>TALARN</td><td>1,4</td><td>931,1</td><td>923,7</td><td>LLEIDA</td><td>3,3</td><td>0,3</td><td>8,2</td><td>5,7</td><td>3,2</td
# %% [markdown]
# + **Altitud:** Altitud de la estación, en metros
# + **dir:** Dirección del viento, en decenas de grado
# + **fecha:** fecha de medicion del valor
# + **horaPresMax:** Hora de la presión máxima, redondeada a la hora entera más próxima
# + **horaPresMin:** Hora de la presión mínima, redondeada a la hora entera más próxima
# + **horaracha:** Hora de la racha máxima (en formato hh:mm)
# + **horatmax:** Hora de la temperatura máxima (en formato hh:mm)
# + **horatmin:** Hora de la temperatura mínima (en formato hh:mm)
# + **indicativo:** Indicativo climatológico de la estación
# + **nombre:** Nombre de la estación
# + **prec:** Precipitación diaria, en milímetros
# + **presMax:** Presión máxima diaria, en hPa
# + **presMin:** Presión mínima diaria, en hPa
# + **provincia:** Nombre de la provincia
# + **racha:** Racha máxima del viento, en m/sg
# + **sol:** Duración de la insolación, en horas
# + **tmax:** Temperatura máxima diaria, en grados centígrados
# + **tmed:** Temperatura media diaria, en grados centígrados
# + **tmin:** Temperatura mínima diaria, en grados centígrados
# + **velmedia:** Velocidad media del viento, en m/sg

# %% [markdown]
# ##FWI

# %%
from functools import reduce

def load_table(file_location, 
               table_name, 
               rename_columns=None, 
               file_type="csv", 
               delimiter=";"):
  
  # The applied options are for CSV files. For other file types, these will be ignored.
  df = spark.read.format(file_type) \
    .option("inferSchema", "true") \
    .option("header", "true") \
    .option("sep", delimiter) \
    .load(file_location)
  df.columns
  if rename_columns is not None:
    df = reduce(lambda dfl, x: dfl.withColumnRenamed(x,rename_columns[x]),rename_columns, df)
    df.columns

  # Create a view or table
  df.createOrReplaceTempView(table_name)

  df.write.format("parquet").saveAsTable(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TABLA DEL INDICE FWI POR PROVINCIAS
file_location = "/mnt/IncendiosForestalesCAT/raw/FWI_incendios/"
file_type = "csv"
table_name = "fwi_provincias"

load_table(file_location, table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fwi_provincias = spark.sql("""
SELECT * FROM fwi_provincias WHERE Provincia in ('Barcelona', 'Tarragona', 'Girona', 'Lleida');
""")
display(fwi_provincias)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Provincia</th><th>Niveles</th><th>Enero</th><th>Febrero</th><th>Marzo</th><th>Abril</th><th>Mayo</th><th>Junio</th><th>Julio</th><th>Agosto</th><th>Septiembre</th><th>Octubre</th><th>Noviembre</th><th>Diciembre</th><th>Anual</th><th>Anyo</th></tr></thead><tbody><tr><td>Barcelona</td><td>Bajo</td><td>22,58</td><td>14,29</td><td>0</td><td>66,67</td><td>58,06</td><td>20</td><td>9,68</td><td>0</td><td>23,33</td><td>38,71</td><td>53,33</td><td>83,87</td><td>32,6</td><td>2019</td></tr><tr><td>Barcelona</td><td>Moderado</td><td>54,84</td><td>39,29</td><td>19,35</td><td>13,33</td><td>29,03</td><td>20</td><td>19,35</td><td>12,9</td><td>36,67</td><td>16,13</td><td>43,33</td><td>16,13</td><td>26,58</td><td>2019</td></tr><tr><td>Barcelona</td><td>Alto</td><td>22,58</td><td>46,43</td><td>51,61</td><td>10</td><td>12,9</td><td>26,67</td><td>12,9</td><td>16,13</td><td>40</td><td>45,16</td><td>3,33</td><td>0</td><td>23,84</td><td>2019</td></tr><tr><td>Barcelona</td><td>Muy_Alto</td><td>0</td><td>0</td><td>29,03</td><td>10</td><td>0</td><td>23,33</td><td>25,81</td><td>45,16</td><td>0</td><td>0</td><td>0</td><td>0</td><td>11,23</td><td>2019</td></tr><tr><td>Barcelona</td><td>Extremo</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td