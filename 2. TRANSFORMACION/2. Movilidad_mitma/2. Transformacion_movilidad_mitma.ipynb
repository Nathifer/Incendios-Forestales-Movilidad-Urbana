# %%
#Paquetes
from pyspark.sql.functions import *
import pyspark.sql.functions as F
from functools import reduce
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from functools import reduce

def load_table(file_location, 
               table_name, 
               rename_columns=None, 
               file_type="csv", 
               delimiter=";"):
  
  # The applied options are for CSV files. For other file types, these will be ignored.
  df = spark.read.format(file_type) \
    .option("inferSchema", "true") \
    .option("header", "true") \
    .option("sep", delimiter) \
    .load(file_location)
  df.columns
  if rename_columns is not None:
    df = reduce(lambda dfl, x: dfl.withColumnRenamed(x,rename_columns[x]),rename_columns, df)
    df.columns

  # Create a view or table
  df.createOrReplaceTempView(table_name)

  # Since this table is registered as a temp view, it will only be available to this notebook. If you'd like other users to be able to query  this table, you can also create a table from the DataFrame.
  # Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
  # To do so, choose your table name and uncomment the bottom line.

  df.write.format("parquet").saveAsTable(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#RAW DATA
df_movilidad = spark.read.format("parquet") \
.load("/mnt/IncendiosForestalesCAT/raw/mitma/movilidad/maestra1/municipios")
display(df_movilidad)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fecha</th><th>origen</th><th>destino</th><th>periodo</th><th>distancia</th><th>viajes</th><th>viajes_km</th><th>cod_mun_origen</th><th>cod_mun_destino</th><th>filename</th><th>year</th><th>month</th></tr></thead><tbody><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>0</td><td>002-005</td><td>29.629</td><td>111.63</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>0</td><td>005-010</td><td>30.171</td><td>222.104</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>0</td><td>010-050</td><td>20.205</td><td>214.927</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>1</td><td>002-005</td><td>42.537</td><td>167.209</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>1</td><td>005-010</td><td>35.103</td><td>253.545</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>1</td><td>010-050</td><td>20.593</td><td>256.595</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>2</td><td>002-005</td><td>20.866</td><td>61.994</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>2</td><td>005-010</td><td>12.674</td><td>105.811</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>3</td><td>002-005</td><td>21.649</td><td>55.126</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>3</td><td>005-010</td><td>6.694</td><td>46.077</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>4</td><td>002-005</td><td>9.79</td><td>20.174</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>4</td><td>005-010</td><td>7.171</td><td>38.709</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>5</td><td>002-005</td><td>32.76</td><td>109.51</td><td>01001</td><td>01001</td><td>dbfs:/mnt/movilidadforest2020/movilidad/maestra1/municipios/20200724_maestra_1_mitma_municipio.txt.gz</td><td>2020</td><td>7</td></tr><tr><td>20200724</td><td>01001_AM</td><td>01001_AM</td><td>5 ...

# %% [markdown]
# # Relación municipios MITMA - Tablas INE

# %%
# Relacion Municipio - Municipio mitma
file_location = "/mnt/IncendiosForestalesCAT/raw/mitma/rl_municipio_mitma/"
permanent_table_name = "rl_municipio_mitma"
dbutils.fs.rm(f"/user/hive/warehouse/{permanent_table_name}/", True)

load_table(file_location, permanent_table_name,delimiter="|")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # INE
# ### Municipios INE

# %%
# TABLA DEL INE CODIGO DE MUNCIPIOS - CODIGO MITMA
dbutils.fs.rm("/user/hive/warehouse/nacional_moviles/", True)
file_location = "/mnt/IncendiosForestalesCAT/raw/mitma/nacional_moviles/"
file_type = "csv"
table_name = "nacional_moviles"

load_table(file_location, table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
municipios_catalunya_INE = spark.sql("""
SELECT * FROM nacional_moviles WHERE NPRO in ('Barcelona', 'Tarragona', 'Girona', 'Lleida');
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(municipios_catalunya_INE)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CUMUN</th><th>CPRO</th><th>NPRO</th><th>NMUN</th><th>AREA_GEO</th><th>ID_AREA_GEO</th><th>POB_AREA_GEO</th><th>COD_LITERAL_SCD</th><th>ID_GRUPO</th><th>POB_GRUPO</th><th>ID_COMPLETO_GRUPO</th><th>LITERAL_GRUPO</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th></tr></thead><tbody><tr><td>8038</td><td>8</td><td>Barcelona</td><td>Callús</td><td>MUNICIPIO</td><td>08038</td><td>2140</td><td>null</td><td>001B</td><td>14529</td><td>08038 Callús</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8084</td><td>8</td><td>Barcelona</td><td>Fonollosa</td><td>MUNICIPIO</td><td>08084</td><td>1453</td><td>null</td><td>001B</td><td>14529</td><td>08084 Fonollosa</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8218</td><td>8</td><td>Barcelona</td><td>Sant Joan de Vilatorrada</td><td>MUNICIPIO</td><td>08218</td><td>10936</td><td>null</td><td>001B</td><td>14529</td><td>08218 Sant Joan de Vilatorrada</td><td>Sant Joan de Vilatorrada y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8021</td><td>8</td><td>Barcelona</td><td>Bellprat</td><td>MUNICIPIO</td><td>08021</td><td>64</td><td>null</td><td>002B</td><td>6522</td><td>08021 Bellprat</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8063</td><td>8</td><td>Barcelona</td><td>Castellolí</td><td>MUNICIPIO</td><td>08063</td><td>619</td><td>null</td><td>002B</td><td>6522</td><td>08063 Castellolí</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8103</td><td>8</td><td>Barcelona</td><td>Jorba</td><td>MUNICIPIO</td><td>08103</td><td>835</td><td>null</td><td>002B</td><td>6522</td><td>08103 Jorba</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8143</td><td>8</td><td>Barcelona</td><td>Òdena</td><td>MUNICIPIO</td><td>08143</td><td>3643</td><td>null</td><td>002B</td><td>6522</td><td>08143 Òdena</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8226</td><td>8</td><td>Barcelona</td><td>Sant Martí de Tous</td><td>MUNICIPIO</td><td>08226</td><td>1235</td><td>null</td><td>002B</td><td>6522</td><td>08226 Sant Martí de Tous</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8257</td><td>8</td><td>Barcelona</td><td>Santa Maria de Miralles</td><td>MUNICIPIO</td><td>08257</td><td>126</td><td>null</td><td>002B</td><td>6522</td><td>08257 Santa Maria de Miralles</td><td>Òdena y otros municipios</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8165</td><td>8</td><td>Barcelona</td><td>Pobla de Claramunt, La</td><td>MUNICIPIO</td><td>08165</td><td>2193</td><td>null</td><td>003B</td><td>5907</td><td>08165 Pobla de Claramunt, La</td><td>Torre de Claramunt, La y Pobla de Claramunt, La</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8286</td><td>8</td><td>Barcelona</td><td>Torre de Claramunt, La</td><td>MUNICIPIO</td><td>08286</td><td>3714</td><td>null</td><td>003B</td><td>5907</td><td>08286 Torre de Claramunt, La</td><td>Torre de Claramunt, La y Pobla de Claramunt, La</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8044</td><td>8</td><td>Barcelona</td><td>Capellades</td><td>MUNICIPIO</td><td>08044</td><td>5293</td><td>null</td><td>004B</td><td>6666</td><td>08044 Capellades</td><td>Capellades y Vallbona d'Anoia</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>8292</td><td>8</td><td>Barcelona</td><td>Vallbona d'Anoia</td><td>MUNICIPIO</td><td>08292</td><td>1373</td><td>null</td><td>004B</td><td>6666</td><td>08292 Vallbona d'Anoia</td><td>Capellades y Vallbona d'Anoia</td><td>null</td><td>null</td ...

# %%
municipiosDF = spark.sql("""
select nm.CUMUN as cod_mun_ine, nm.ID_AREA_GEO as cod_area_ine, mm.municipio as cod_mun_mitma_movilidad ,nm.NMUN as nombre_municipio, nm.CPRO as cod_provincia, nm.NPRO as nombre_provincia, mm.municipio_mitma
FROM nacional_moviles as nm
JOIN rl_municipio_mitma as mm ON  nm.CUMUN = mm.municipio
WHERE nm.CUMUN == mm.municipio AND NPRO in ("Barcelona", "Lleida", "Tarragona", "Girona")""")

display(municipiosDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cod_mun_ine</th><th>cod_area_ine</th><th>cod_mun_mitma_movilidad</th><th>nombre_municipio</th><th>cod_provincia</th><th>nombre_provincia</th><th>municipio_mitma</th></tr></thead><tbody><tr><td>8038</td><td>08038</td><td>8038</td><td>Callús</td><td>8</td><td>Barcelona</td><td>08218_AM</td></tr><tr><td>8084</td><td>08084</td><td>8084</td><td>Fonollosa</td><td>8</td><td>Barcelona</td><td>08218_AM</td></tr><tr><td>8218</td><td>08218</td><td>8218</td><td>Sant Joan de Vilatorrada</td><td>8</td><td>Barcelona</td><td>08218_AM</td></tr><tr><td>8021</td><td>08021</td><td>8021</td><td>Bellprat</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8063</td><td>08063</td><td>8063</td><td>Castellolí</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8103</td><td>08103</td><td>8103</td><td>Jorba</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8143</td><td>08143</td><td>8143</td><td>Òdena</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8226</td><td>08226</td><td>8226</td><td>Sant Martí de Tous</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8257</td><td>08257</td><td>8257</td><td>Santa Maria de Miralles</td><td>8</td><td>Barcelona</td><td>08143_AM</td></tr><tr><td>8165</td><td>08165</td><td>8165</td><td>Pobla de Claramunt, La</td><td>8</td><td>Barcelona</td><td>08286_AM</td></tr><tr><td>8286</td><td>08286</td><td>8286</td><td>Torre de Claramunt, La</td><td>8</td><td>Barcelona</td><td>08286_AM</td></tr><tr><td>8044</td><td>08044</td><td>8044</td><td>Capellades</td><td>8</td><td>Barcelona</td><td>08044_AM</td></tr><tr><td>8292</td><td>08292</td><td>8292</td><td>Vallbona d'Anoia</td><td>8</td><td>Barcelona</td><td>08044_AM</td></tr><tr><td>8028</td><td>08028</td><td>8028</td><td>Cabrera d'Anoia</td><td>8</td><td>Barcelona</td><td>08122_AM</td></tr><tr><td>8122</td><td>08122</td><td>8122</td><td>Mediona</td><td>8</td><td>Barcelona</td><td>08122_AM</td></tr><tr><td>8236</td><td>08236</td><td>8236</td><td>Sant Quintí de Mediona</td><td>8</td><td>Barcelona</td><td>08122_AM</td></tr><tr><td>8146</td><td>08146</td><td>8146</td><td>Olesa de Bonesvalls</td><td>8</td><td>Barcelona</td><td>08273_AM</td></tr><tr><td>8273</td><td>08273</td><td>8273</td><td>Subirats</td><td>8</td><td>Barcelona</td><td>08273_AM</td></tr><tr><td>8053</td><td>08053</td><td>8053</td><td>Castellbell i el Vilar</td><td>8</td><td>Barcelona</td><td>08053_AM</td></tr><tr><td>8127</td><td>08127</td><td>8127</td><td>Monistrol de Montserrat</td><td>8</td><td>Barcelona</td><td>08053_AM</td></tr><tr><td>8242</td><td>08242</td><td>8242</td><td>Marganell</td><td>8</td><td>Barcelona</td><td>08053_AM</td></tr><tr><td>8061</td><td>08061</td><td>8061</td><td>Castellgalí</td><td>8</td><td>Barcelona</td><td>08098_AM</td></tr><tr><td>8179</td><td>08179</td><td>8179</td><td>Rellinars</td><td>8</td><td>Barcelona</td><td>08262_AM</td></tr><tr><td>8262</td><td>08262</td><td>8262</td><td>Sant Vicenç de Castellet</td><td>8</td><td>Barcelona</td><td>08262_AM</td></tr><tr><td>8025</td><td>08025</td><td>8025</td><td>Bruc, El</td><td>8</td><td>Barcelona</td><td>08162_AM</td></tr><tr><td>8162</td><td>08162</td><td>8162</td><td>Hostalets de Pierola, Els</td><td>8</td><td>Barcelona</td><td>08162_AM</td></tr><tr><td>8290</td><td>08290</td><td>8290</td><td>Ullastrell</td><td>8</td><td>Barcelona</td><td>08300_AM</td></tr><tr><td>8300</td><td>08300</td><td>8300</td><td>Viladecavalls</td><td>8</td><td>Barcelona</td><td>08300_AM</td></tr><tr><td>8208</td><td>08208</td><td>8208</td><td>Sant Esteve Sesrovires</td><td>8</td><td>Barcelona</td><td>08208_AM</td></tr><tr><td>8222</td><td>08222</td><td>8222</td><td>Sant Llorenç d'Hortons</td><td>8</td><td>Barcelona</td><td>08208_AM</td></tr><tr><td>8066</td><td>08066</td><td>8066</td><td>Castellví de Rosanes</td><td>8</td><td>Barcelona</td><td>08091_AM</td></tr><tr><td>8091</td><td>08091</td><td>8 ...

# %%
#Join de las tablas  df_movilidad  y municipiosDF
df_movilidad =df_movilidad.join(municipiosDF,df_movilidad.destino ==  municipiosDF.municipio_mitma,"inner")
df_movilidad.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: 628986991</div>

# %%
from pyspark.sql import Window
windowSpecAgg  = Window.partitionBy("fecha", "destino")

df_movilidad_agg = df_movilidad.withColumn("total_viajes", F.sum(F.col("viajes")).over(windowSpecAgg)) \
.withColumn("total_viajes_km", F.sum(F.col("viajes_km")).over(windowSpecAgg))
df_movilidad_agg_unique = df_movilidad_agg.dropDuplicates(["fecha", "destino"])
df_movilidad_agg_unique.persist()

#Change format
df_movilidad_agg_unique= df_movilidad_agg_unique\
.withColumn("fecha", F.to_date(F.col("fecha").cast("string"),'yyyy-MM-dd'))\
.withColumn('fecha', F.col("fecha").cast("string"))\
.withColumn("cod_mun_destino", F.col("cod_mun_destino").cast("integer"))


#Write to S3
columns = ['fecha', 'year', 'month' ,'destino', 'cod_mun_destino', 'cod_mun_ine', 'nombre_municipio', 'cod_provincia', 'nombre_provincia', 'total_viajes', 'total_viajes_km']
df_movilidad_agg_unique.select(columns).write.mode("overwrite").partitionBy("year","month").parquet(f"/mnt/IncendiosForestalesCAT/prep/mitma/movilidad/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
display(df_movilidad_agg_unique)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fecha</th><th>destino</th><th>cod_mun_destino</th><th>cod_mun_ine</th><th>nombre_municipio</th><th>cod_provincia</th><th>nombre_provincia</th><th>total_viajes</th><th>total_viajes_km</th><th>year</th><th>month</th></tr></thead><tbody><tr><td>2020-12-01</td><td>08031_AM</td><td>8031</td><td>8002</td><td>Aguilar de Segarra</td><td>8</td><td>Barcelona</td><td>361708.99499999883</td><td>6821802.045000114</td><td>2020</td><td>12</td></tr><tr><td>2020-12-01</td><td>08155_AM</td><td>8155</td><td>8155</td><td>Palafolls</td><td>8</td><td>Barcelona</td><td>105027.38999999953</td><td>907172.568</td><td>2020</td><td>12</td></tr><tr><td>2020-12-01</td><td>08235</td><td>8235</td><td>8235</td><td>Sant Pol de Mar</td><td>8</td><td>Barcelona</td><td>9594.482999999986</td><td>94310.10000000003</td><td>2020</td><td>12</td></tr><tr><td>2020-12-01</td><td>08238</td><td>8238</td><td>8238</td><td>Sant Quirze del Vallès</td><td>8</td><td>Barcelona</td><td>62554.402999999984</td><td>391881.7050000002</td><td>2020</td><td>12</td></tr><tr><td>2020-12-01</td><td>17007_AM</td><td>17007</td><td>17007</td><td>Amer</td><td>17</td><td>Girona</td><td>167169.63199999902</td><td>2311569.9599999837</td><td>2020</td><td>12</td></tr><tr><td>2020-12-01</td><td>25008_AM</td><td>25008</td><td>25008</td><td>Albesa</td><td>25</td><td>Lleida</td><td>74376.75000000017</td><td>1025929.1640000007</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>08031_AM</td><td>8031</td><td>8002</td><td>Aguilar de Segarra</td><td>8</td><td>Barcelona</td><td>349045.09500001016</td><td>7002079.485000094</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>08155_AM</td><td>8155</td><td>8155</td><td>Palafolls</td><td>8</td><td>Barcelona</td><td>102280.32599999986</td><td>886457.6339999989</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>08235</td><td>8235</td><td>8235</td><td>Sant Pol de Mar</td><td>8</td><td>Barcelona</td><td>9774.138999999994</td><td>90927.37700000002</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>08238</td><td>8238</td><td>8238</td><td>Sant Quirze del Vallès</td><td>8</td><td>Barcelona</td><td>63039.94699999997</td><td>386234.35300000035</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>17007_AM</td><td>17007</td><td>17007</td><td>Amer</td><td>17</td><td>Girona</td><td>168606.53600000084</td><td>2179365.175999987</td><td>2020</td><td>12</td></tr><tr><td>2020-12-02</td><td>25008_AM</td><td>25008</td><td>25008</td><td>Albesa</td><td>25</td><td>Lleida</td><td>74495.96399999963</td><td>1054980.857999993</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>08031_AM</td><td>8031</td><td>8002</td><td>Aguilar de Segarra</td><td>8</td><td>Barcelona</td><td>364888.8600000066</td><td>6557013.480000009</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>08155_AM</td><td>8155</td><td>8155</td><td>Palafolls</td><td>8</td><td>Barcelona</td><td>105841.14999999944</td><td>985412.098000002</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>08235</td><td>8235</td><td>8235</td><td>Sant Pol de Mar</td><td>8</td><td>Barcelona</td><td>10517.171000000028</td><td>117589.16500000001</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>08238</td><td>8238</td><td>8238</td><td>Sant Quirze del Vallès</td><td>8</td><td>Barcelona</td><td>61603.57200000012</td><td>387379.26100000064</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>17007_AM</td><td>17007</td><td>17007</td><td>Amer</td><td>17</td><td>Girona</td><td>168811.8080000021</td><td>2595432.5679999655</td><td>2020</td><td>12</td></tr><tr><td>2020-12-03</td><td>25008_AM</td><td>25008</td><td>25008</td><td>Albesa</td><td>25</td><td>Lleida</td><td>64865.57399999963</td><td>967843.4760000004</td><td>2020</td><td>12</td></tr><tr><td>2020-12-04</td><td>08031_AM</td><td>8031</td><td>8002</td><td>Aguilar de Segarra</td><td>8</td><td>Barcelona</td><td ...
