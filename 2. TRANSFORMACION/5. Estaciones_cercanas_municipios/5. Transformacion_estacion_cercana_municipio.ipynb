# %% [markdown]
# #### Actualmente hay 741 municipios donde hubo incendio y solo tenemos 233 estaciones metorológicas. Por lo que si hacemos join de incencios con valores meteorológicos perderemos muchos datos sobre incendios.
# #### El objetivo es tratar de asignar la estacion meteorológica XEMA más cercana  a cada municicipio.

# %%
# !pip install geopy tqdm
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: geopy in /databricks/python3/lib/python3.8/site-packages (2.3.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.8/site-packages (4.64.1)
# Requirement already satisfied: geographiclib&lt;3,&gt;=1.52 in /databricks/python3/lib/python3.8/site-packages (from geopy) (2.0)
# <span class="ansi-yellow-fg">WARNING: You are using pip version 21.0.1; however, version 22.3.1 is available.
# You should consider upgrading via the &#39;/databricks/python3/bin/python -m pip install --upgrade pip&#39; command.</span>
# </div>

# %%
from functools import reduce
import pyspark.sql.functions as F
from geopy.geocoders import Nominatim
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number
from pyspark.sql.types import StringType
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#parquet
incendios_ocurridos_CATDF = spark.read.format("parquet") \
.load("/mnt/IncendiosForestalesCAT/raw/meteocat/incendios_forestales") \
.select(["codi_municipi","termemunic"]) \
.withColumnRenamed("termemunic","municipio") \
.withColumnRenamed("codi_municipi","codigo_municipio")

#parquet
alt_pend_riscDF = spark.read.format("parquet") \
.load("/mnt/IncendiosForestalesCAT/prep/alt_pend_risc") \
.select(["cod_idescat","municipio"]) \
.withColumnRenamed("cod_idescat","codigo_municipio")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
incendios_ocurridos_CATDF.select(["municipio"]).distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: 741</div>

# %%
alt_pend_riscDF.select(["municipio"]).distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 946</div>

# %%
# Obtener municipios que no tienen datos meteo
muni_incendios= incendios_ocurridos_CATDF.distinct()
muni_risc =alt_pend_riscDF.distinct()
missing_muni = muni_risc.alias("df1").join(muni_incendios.alias("df2"), F.col("df1.codigo_municipio")==F.col("df2.codigo_municipio"),"left")
missing_muni.filter(F.col("df2.municipio").isNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 206</div>

# %%
missing_muni=missing_muni.select("df1.*")
display(missing_muni)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>codigo_municipio</th><th>municipio</th></tr></thead><tbody><tr><td>89019</td><td>Rupit i Pruit</td></tr><tr><td>431711</td><td>Vila-seca</td></tr><tr><td>250241</td><td>Alt Àneu</td></tr><tr><td>82074</td><td>Sant Esteve de Palautordera</td></tr><tr><td>80790</td><td>Estany, l'</td></tr><tr><td>80272</td><td>Cabanyes, les</td></tr><tr><td>82270</td><td>Sant Martí Sarroca</td></tr><tr><td>170524</td><td>Siurana</td></tr><tr><td>430976</td><td>Nou de Gaià, la</td></tr><tr><td>81115</td><td>Malla</td></tr><tr><td>171886</td><td>Selva de Mar, la</td></tr><tr><td>430939</td><td>Móra d'Ebre</td></tr><tr><td>170010</td><td>Agullana</td></tr><tr><td>251713</td><td>Pobla de Segur, la</td></tr><tr><td>80060</td><td>Arenys de Mar</td></tr><tr><td>80155</td><td>Badalona</td></tr><tr><td>431750</td><td>Vilalba dels Arcs</td></tr><tr><td>431172</td><td>Prat de Comte</td></tr><tr><td>250753</td><td>Clariana de Cardener</td></tr><tr><td>252094</td><td>Sort</td></tr><tr><td>81228</td><td>Mediona</td></tr><tr><td>252424</td><td>Verdú</td></tr><tr><td>251636</td><td>Coma i la Pedra, la</td></tr><tr><td>81712</td><td>Prats de Lluçanès</td></tr><tr><td>81173</td><td>Masies de Voltregà, les</td></tr><tr><td>430995</td><td>Palma d'Ebre, la</td></tr><tr><td>250485</td><td>Bell-lloc d'Urgell</td></tr><tr><td>82460</td><td>Santa Eugènia de Berga</td></tr><tr><td>250851</td><td>Estaràs</td></tr><tr><td>431515</td><td>Torre de Fontaubella, la</td></tr><tr><td>250693</td><td>Castelló de Farfanya</td></tr><tr><td>82227</td><td>Sant Llorenç d'Hortons</td></tr><tr><td>83054</td><td>Vilafranca del Penedès</td></tr><tr><td>259062</td><td>Valls d'Aguilar, les</td></tr><tr><td>170963</td><td>Llosses, les</td></tr><tr><td>252173</td><td>Tàrrega</td></tr><tr><td>82858</td><td>Torelló</td></tr><tr><td>80039</td><td>Alella</td></tr><tr><td>80522</td><td>Castellar de n'Hug</td></tr><tr><td>171772</td><td>Sant Pau de Segúries</td></tr><tr><td>80229</td><td>Berga</td></tr><tr><td>251410</td><td>Montoliu de Segarra</td></tr><tr><td>250946</td><td>Foradada</td></tr><tr><td>170932</td><td>Llers</td></tr><tr><td>430764</td><td>Marçà</td></tr><tr><td>82251</td><td>Sant Martí d'Albars</td></tr><tr><td>430786</td><td>Masdenverge</td></tr><tr><td>80636</td><td>Castellolí</td></tr><tr><td>81483</td><td>Olivella</td></tr><tr><td>170025</td><td>Aiguaviva</td></tr><tr><td>430402</td><td>Capçanes</td></tr><tr><td>171024</td><td>Maçanet de Cabrenys</td></tr><tr><td>252458</td><td>Vilaller</td></tr><tr><td>80689</td><td>Cervelló</td></tr><tr><td>171096</td><td>Montagut i Oix</td></tr><tr><td>82055</td><td>Sant Cugat del Vallès</td></tr><tr><td>431074</td><td>Pira</td></tr><tr><td>250899</td><td>Farrera</td></tr><tr><td>82554</td><td>Santa Maria de Merlès</td></tr><tr><td>80765</td><td>Esparreguera</td></tr><tr><td>82188</td><td>Sant Joan de Vilatorrada</td></tr><tr><td>170985</td><td>Maià de Montcal</td></tr><tr><td>250501</td><td>Bellpuig</td></tr><tr><td>250208</td><td>Almatret</td></tr><tr><td>431227</td><td>Renau</td></tr><tr><td>431378</td><td>Sant Jaume dels Domenys</td></tr><tr><td>80168</td><td>Bagà</td></tr><tr><td>80902</td><td>Gaià</td></tr><tr><td>251930</td><td>Sant Llorenç de Morunys</td></tr><tr><td>82763</td><td>Tagamanent</td></tr><tr><td>430290</td><td>Blancafort</td></tr><tr><td>251266</td><td>Llavorsí</td></tr><tr><td>179032</td><td>Sant Julià del Llor i Bonmatí</td></tr><tr><td>172039</td><td>Ultramort</td></tr><tr><td>80076</td><td>Arenys de Munt</td></tr><tr><td>251500</td><td>Oliola</td></tr><tr><td>430326</td><td>Bot</td></tr><tr><td>80291</td><td>Cabrera de Mar</td></tr><tr><td>82975</td><td>Veciana</td></tr><tr><td>430287</td><td>Bisbal del Penedès, la</td></tr><tr><td>171289</td><td>Pau</td></tr><tr><td>430509</td><td>Creixell</td></tr><tr><td>251898</td><td>Rosselló</td></tr><tr><td>170545</td><td>Colera</td></tr><tr><td>172095</td><td>Va ...

# %% [markdown]
# Solo tenemos 1 municipio sin datos de cartografia, riesgo incendio y 206 municipios que no tenemos en la tabla incendio.
# Por lo tanto se analizará calculará la distancia entre municipios de alt_pend_riscDF y las estaciones AEMET y Meteocat

# %%
estaciones_meteocatDF = spark.read.parquet("/mnt/IncendiosForestalesCAT/raw/meteocat/estaciones/")\
.filter(F.col("data_fi") >= "nan")\
.select(["codi_estacio", "latitud", "longitud", "nom_municipi"])\
.withColumnRenamed("codi_estacio","indicativo")\
.withColumnRenamed("nom_municipi","nombre")
display(estaciones_meteocatDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>indicativo</th><th>latitud</th><th>longitud</th><th>nombre</th></tr></thead><tbody><tr><td>X4</td><td>41.3839</td><td>2.16775</td><td>Barcelona</td></tr><tr><td>YG</td><td>42.51881</td><td>1.24244</td><td>Tírvia</td></tr><tr><td>VY</td><td>41.25095</td><td>1.29863</td><td>Nulles</td></tr><tr><td>YD</td><td>41.51135</td><td>0.85617</td><td>Les Borges Blanques</td></tr><tr><td>VD</td><td>41.68939</td><td>1.20381</td><td>Els Plans de Sió</td></tr><tr><td>WX</td><td>41.9178</td><td>0.88175</td><td>Camarasa</td></tr><tr><td>XV</td><td>41.48311</td><td>2.07956</td><td>Sant Cugat del Vallès</td></tr><tr><td>U1</td><td>42.30648</td><td>2.95481</td><td>Cabanes</td></tr><tr><td>CY</td><td>41.87813</td><td>2.17873</td><td>Muntanyola</td></tr><tr><td>D6</td><td>42.43515</td><td>3.16622</td><td>Portbou</td></tr><tr><td>D3</td><td>41.38197</td><td>1.93564</td><td>Vallirana</td></tr><tr><td>Z1</td><td>42.64691</td><td>0.98486</td><td>Alt Àneu</td></tr><tr><td>X1</td><td>41.15374</td><td>0.81953</td><td>Falset</td></tr><tr><td>VH</td><td>41.65814</td><td>0.39301</td><td>Gimenells i el Pla de la Font</td></tr><tr><td>WK</td><td>41.81949</td><td>0.57768</td><td>Alfarràs</td></tr><tr><td>YL</td><td>41.1227</td><td>0.96951</td><td>Riudecanyes</td></tr><tr><td>CT</td><td>42.39811</td><td>0.74362</td><td>El Pont de Suert</td></tr><tr><td>XR</td><td>41.31481</td><td>0.98161</td><td>Prades</td></tr><tr><td>H1</td><td>41.58642</td><td>1.65306</td><td>Òdena</td></tr><tr><td>UE</td><td>42.02306</td><td>3.15719</td><td>Torroella de Montgrí</td></tr><tr><td>W4</td><td>41.36619</td><td>1.72857</td><td>La Granada</td></tr><tr><td>X3</td><td>41.74281</td><td>0.5358</td><td>Alguaire</td></tr><tr><td>US</td><td>40.55786</td><td>0.52329</td><td>Alcanar</td></tr><tr><td>KP</td><td>41.73894</td><td>2.69436</td><td>Fogars de la Selva</td></tr><tr><td>XD</td><td>41.32</td><td>0.8857</td><td>Ulldemolins</td></tr><tr><td>XY</td><td>41.56509</td><td>0.55027</td><td>Alcarràs</td></tr><tr><td>CJ</td><td>42.21624</td><td>1.33132</td><td>Organyà</td></tr><tr><td>U9</td><td>40.76947</td><td>0.61635</td><td>L'Aldea</td></tr><tr><td>YB</td><td>42.18813</td><td>2.47097</td><td>Olot</td></tr><tr><td>D1</td><td>41.28521</td><td>0.75383</td><td>Margalef</td></tr><tr><td>XG</td><td>41.56734</td><td>2.22619</td><td>Parets del Vallès</td></tr><tr><td>UF</td><td>41.28832</td><td>1.90775</td><td>Begues</td></tr><tr><td>Z3</td><td>42.46605</td><td>1.7785</td><td>Meranges</td></tr><tr><td>CE</td><td>41.53109</td><td>1.80813</td><td>Els Hostalets de Pierola</td></tr><tr><td>CU</td><td>42.69856</td><td>0.79397</td><td>Vielha e Mijaran</td></tr><tr><td>WI</td><td>41.35741</td><td>0.4809</td><td>Maials</td></tr><tr><td>UW</td><td>40.62725</td><td>0.65922</td><td>Sant Carles de la Ràpita</td></tr><tr><td>CC</td><td>42.07398</td><td>2.20862</td><td>Orís</td></tr><tr><td>W8</td><td>41.44237</td><td>1.15998</td><td>Blancafort</td></tr><tr><td>C6</td><td>41.6566</td><td>0.95172</td><td>Castellnou de Seana</td></tr><tr><td>WO</td><td>41.27151</td><td>1.46717</td><td>La Bisbal del Penedès</td></tr><tr><td>VU</td><td>41.63286</td><td>1.91718</td><td>Rellinars</td></tr><tr><td>WQ</td><td>42.0513</td><td>0.72952</td><td>Sant Esteve de la Sarga</td></tr><tr><td>XQ</td><td>42.16252</td><td>0.88814</td><td>Tremp</td></tr><tr><td>WB</td><td>41.76036</td><td>0.67022</td><td>Albesa</td></tr><tr><td>DQ</td><td>41.30728</td><td>1.36259</td><td>Vila-rodona</td></tr><tr><td>UI</td><td>42.26477</td><td>1.76218</td><td>Gisclareny</td></tr><tr><td>DK</td><td>41.14677</td><td>1.41846</td><td>Torredembarra</td></tr><tr><td>J5</td><td>42.34215</td><td>2.83423</td><td>Darnius</td></tr><tr><td>Y9</td><td>41.31723</td><td>2.13091</td><td>El Prat de Llobregat</td></tr><tr><td>WG</td><td>41.80104</td><td>0.64804</td><td>Algerri</td></tr><tr><td>UJ</td><td>41.52879</td><td>1.3683</td><td>Santa Coloma de  ...

# %%
@udf(returnType=StringType())
def convertToDec(coord_str):
    """
    Convertir coordenada con formato grados, minutos, segundos a decimales
    """
    direction = coord_str[-1]
    coord = (int(coord_str[:2]) +int(coord_str[2:4])/60 +float(coord_str[4:6])/3600)* (-1 if direction in ['W', 'S'] else 1)
    return (f"{coord}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
estaciones_aemetDF = spark.read.parquet("/mnt/IncendiosForestalesCAT/raw/aemet/estaciones/")\
.filter(F.col("provincia").isin(["BARCELONA", "TARRAGONA", "GIRONA", "LLEIDA"]))\
.select(["indicativo", "latitud", "longitud", "nombre"]) \
.withColumn("latitud", convertToDec(F.col("latitud"))) \
.withColumn("longitud", convertToDec(F.col("longitud")))
display(estaciones_aemetDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>indicativo</th><th>latitud</th><th>longitud</th><th>nombre</th></tr></thead><tbody><tr><td>0252D</td><td>41.587500000000006</td><td>2.54</td><td>ARENYS DE MAR</td></tr><tr><td>0076</td><td>41.29277777777778</td><td>2.0700000000000003</td><td>BARCELONA AEROPUERTO</td></tr><tr><td>0200E</td><td>41.41833333333333</td><td>2.1241666666666665</td><td>BARCELONA, FABRA</td></tr><tr><td>0201D</td><td>41.39055555555556</td><td>2.2</td><td>BARCELONA</td></tr><tr><td>0149X</td><td>41.72</td><td>1.840277777777778</td><td>MANRESA</td></tr><tr><td>0229I</td><td>41.52361111111111</td><td>2.1030555555555557</td><td>SABADELL AEROPUERTO</td></tr><tr><td>0255B</td><td>41.65083333333333</td><td>2.6969444444444446</td><td>SANTA SUSANNA</td></tr><tr><td>0367</td><td>41.91166666666666</td><td>2.763333333333333</td><td>GIRONA AEROPUERTO</td></tr><tr><td>0370B</td><td>41.980000000000004</td><td>2.8252777777777776</td><td>GIRONA, ANTIC INSTITUT</td></tr><tr><td>0372C</td><td>42.10444444444445</td><td>2.763611111111111</td><td>PORQUERES</td></tr><tr><td>0324A</td><td>42.19138888888889</td><td>2.196111111111111</td><td>RIPOLL</td></tr><tr><td>0016A</td><td>41.144999999999996</td><td>1.163611111111111</td><td>REUS AEROPUERTO</td></tr><tr><td>0002I</td><td>40.95805555555556</td><td>0.8713888888888889</td><td>VANDELLÒS  </td></tr><tr><td>9585</td><td>42.3325</td><td>1.9394444444444445</td><td>LA MOLINA</td></tr><tr><td>9619</td><td>42.35472222222222</td><td>1.4630555555555556</td><td>LA SEU D'URGELL</td></tr><tr><td>9771</td><td>41.617222222222225</td><td>0.6211111111111112</td><td>LLEIDA, OBSERVATORIO</td></tr><tr><td>9771C</td><td>41.626111111111115</td><td>0.5980555555555556</td><td>LLEIDA</td></tr><tr><td>9990X</td><td>42.70027777777778</td><td>0.8769444444444445</td><td>NAUT ARAN, ARTIES </td></tr><tr><td>9698U</td><td>42.20527777777778</td><td>0.8652777777777777</td><td>TALARN</td></tr><tr><td>9720X</td><td>41.650555555555556</td><td>1.1494444444444445</td><td>TÀRREGA</td></tr><tr><td>9981A</td><td>40.82027777777778</td><td>0.49333333333333335</td><td>ESTACIÓN DE TORTOSA (ROQUETES)</td></tr><tr><td>9987P</td><td>40.69916666666666</td><td>0.81</td><td>SANT JAUME D'ENVEJA</td></tr></tbody></table></div>

# %%
estacionesDF= estaciones_meteocatDF.union(estaciones_aemetDF)
display(estacionesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>indicativo</th><th>latitud</th><th>longitud</th><th>nombre</th></tr></thead><tbody><tr><td>X4</td><td>41.3839</td><td>2.16775</td><td>Barcelona</td></tr><tr><td>YG</td><td>42.51881</td><td>1.24244</td><td>Tírvia</td></tr><tr><td>VY</td><td>41.25095</td><td>1.29863</td><td>Nulles</td></tr><tr><td>YD</td><td>41.51135</td><td>0.85617</td><td>Les Borges Blanques</td></tr><tr><td>VD</td><td>41.68939</td><td>1.20381</td><td>Els Plans de Sió</td></tr><tr><td>WX</td><td>41.9178</td><td>0.88175</td><td>Camarasa</td></tr><tr><td>XV</td><td>41.48311</td><td>2.07956</td><td>Sant Cugat del Vallès</td></tr><tr><td>U1</td><td>42.30648</td><td>2.95481</td><td>Cabanes</td></tr><tr><td>CY</td><td>41.87813</td><td>2.17873</td><td>Muntanyola</td></tr><tr><td>D6</td><td>42.43515</td><td>3.16622</td><td>Portbou</td></tr><tr><td>D3</td><td>41.38197</td><td>1.93564</td><td>Vallirana</td></tr><tr><td>Z1</td><td>42.64691</td><td>0.98486</td><td>Alt Àneu</td></tr><tr><td>X1</td><td>41.15374</td><td>0.81953</td><td>Falset</td></tr><tr><td>VH</td><td>41.65814</td><td>0.39301</td><td>Gimenells i el Pla de la Font</td></tr><tr><td>WK</td><td>41.81949</td><td>0.57768</td><td>Alfarràs</td></tr><tr><td>YL</td><td>41.1227</td><td>0.96951</td><td>Riudecanyes</td></tr><tr><td>CT</td><td>42.39811</td><td>0.74362</td><td>El Pont de Suert</td></tr><tr><td>XR</td><td>41.31481</td><td>0.98161</td><td>Prades</td></tr><tr><td>H1</td><td>41.58642</td><td>1.65306</td><td>Òdena</td></tr><tr><td>UE</td><td>42.02306</td><td>3.15719</td><td>Torroella de Montgrí</td></tr><tr><td>W4</td><td>41.36619</td><td>1.72857</td><td>La Granada</td></tr><tr><td>X3</td><td>41.74281</td><td>0.5358</td><td>Alguaire</td></tr><tr><td>US</td><td>40.55786</td><td>0.52329</td><td>Alcanar</td></tr><tr><td>KP</td><td>41.73894</td><td>2.69436</td><td>Fogars de la Selva</td></tr><tr><td>XD</td><td>41.32</td><td>0.8857</td><td>Ulldemolins</td></tr><tr><td>XY</td><td>41.56509</td><td>0.55027</td><td>Alcarràs</td></tr><tr><td>CJ</td><td>42.21624</td><td>1.33132</td><td>Organyà</td></tr><tr><td>U9</td><td>40.76947</td><td>0.61635</td><td>L'Aldea</td></tr><tr><td>YB</td><td>42.18813</td><td>2.47097</td><td>Olot</td></tr><tr><td>D1</td><td>41.28521</td><td>0.75383</td><td>Margalef</td></tr><tr><td>XG</td><td>41.56734</td><td>2.22619</td><td>Parets del Vallès</td></tr><tr><td>UF</td><td>41.28832</td><td>1.90775</td><td>Begues</td></tr><tr><td>Z3</td><td>42.46605</td><td>1.7785</td><td>Meranges</td></tr><tr><td>CE</td><td>41.53109</td><td>1.80813</td><td>Els Hostalets de Pierola</td></tr><tr><td>CU</td><td>42.69856</td><td>0.79397</td><td>Vielha e Mijaran</td></tr><tr><td>WI</td><td>41.35741</td><td>0.4809</td><td>Maials</td></tr><tr><td>UW</td><td>40.62725</td><td>0.65922</td><td>Sant Carles de la Ràpita</td></tr><tr><td>CC</td><td>42.07398</td><td>2.20862</td><td>Orís</td></tr><tr><td>W8</td><td>41.44237</td><td>1.15998</td><td>Blancafort</td></tr><tr><td>C6</td><td>41.6566</td><td>0.95172</td><td>Castellnou de Seana</td></tr><tr><td>WO</td><td>41.27151</td><td>1.46717</td><td>La Bisbal del Penedès</td></tr><tr><td>VU</td><td>41.63286</td><td>1.91718</td><td>Rellinars</td></tr><tr><td>WQ</td><td>42.0513</td><td>0.72952</td><td>Sant Esteve de la Sarga</td></tr><tr><td>XQ</td><td>42.16252</td><td>0.88814</td><td>Tremp</td></tr><tr><td>WB</td><td>41.76036</td><td>0.67022</td><td>Albesa</td></tr><tr><td>DQ</td><td>41.30728</td><td>1.36259</td><td>Vila-rodona</td></tr><tr><td>UI</td><td>42.26477</td><td>1.76218</td><td>Gisclareny</td></tr><tr><td>DK</td><td>41.14677</td><td>1.41846</td><td>Torredembarra</td></tr><tr><td>J5</td><td>42.34215</td><td>2.83423</td><td>Darnius</td></tr><tr><td>Y9</td><td>41.31723</td><td>2.13091</td><td>El Prat de Llobregat</td></tr><tr><td>WG</td><td>41.80104</td><td>0.64804</td><td>Algerri</td></tr><tr><td>UJ</td><td>41.52879</td><td>1.3683</td><td>Santa Coloma de  ...

# %%
geolocator = Nominatim(user_agent="https://maps.googleapis.com")
def getCoordinatesbyMuni(munic):
    """
    Funcion para obtener posicion lat lon dado un municipio
    """
    try:
        location = geolocator.geocode(munic)
    except Exception as e:
        print(e)
        return None
    return f"{location.raw.get('lat')} {location.raw.get('lon')}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm

from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="https://maps.googleapis.com")

missing_muniPD = missing_muni.toPandas()

# Se limpia el campo municipio para una mejor precision de la api de google
missing_muniPD['municipio_clean']=missing_muniPD['municipio'].apply(lambda x: x.split(",")[0])
missing_muniPD['municipio_clean'] = missing_muniPD['municipio_clean']+ ', España'

tqdm.pandas()
missing_muniPD['location_code'] = missing_muniPD['municipio_clean'].progress_apply(getCoordinatesbyMuni)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
#  44%|████▍     | 416/946 [03:27&lt;04:24,  2.01it/s]HTTPSConnectionPool(host=&#39;nominatim.openstreetmap.org&#39;, port=443): Max retries exceeded with url: /search?q=Port+de+la+Selva%2C+Espa%C3%B1a&amp;format=json&amp;limit=1 (Caused by ReadTimeoutError(&#34;HTTPSConnectionPool(host=&#39;nominatim.openstreetmap.org&#39;, port=443): Read timed out. (read timeout=1)&#34;))
#  63%|██████▎   | 594/946 [05:01&lt

# %%
missing_muniPD[missing_muniPD['location_code'].isna()]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>codigo_municipio</th>
#       <th>municipio</th>
#       <th>municipio_clean</th>
#       <th>location_code</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#Algunos municipios no se han  podido obtener. Se mapean manualmente
missing_muniPD.loc[missing_muniPD['municipio']=='Port de la Selva, el','location_code']='42.3373159 3.2047232'
# missing_muniPD.loc[missing_muniPD['municipio']=='Pont de Bar, el','location_code'] ='42.3721732 1.6047661'
missing_muniPD.loc[missing_muniPD['municipio']=="Vall d'en Bas, la",'location_code'] ='42.1388600 2.4410500'
# missing_muniPD.loc[missing_muniPD['municipio']=="Ametlla de Mar, l'",'location_code'] ='40.8838957 0.8024645'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
missing_muniDF=spark.createDataFrame(missing_muniPD).select(["municipio","location_code","codigo_municipio"])

missing_muniDF= missing_muniDF.withColumn("municipio_lat", F.split("location_code"," ").getItem(0)) \
.withColumn("municipio_lon", F.split("location_code"," ").getItem(1))
display(missing_muniDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>municipio</th><th>location_code</th><th>codigo_municipio</th><th>municipio_lat</th><th>municipio_lon</th></tr></thead><tbody><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td></tr><tr><td>Vila-seca</td><td>41.1109268 1.144961</td><td>431711</td><td>41.1109268</td><td>1.144961</td></tr><tr><td>Alt Àneu</td><td>42.69035515 1.0624832582072457</td><td>250241</td><td>42.69035515</td><td>1.0624832582072457</td></tr><tr><td>Sant Esteve de Palautordera</td><td>41.7040768 2.4343426</td><td>82074</td><td>41.7040768</td><td>2.4343426</td></tr><tr><td>Estany, l'</td><td>41.8858007 0.3685293</td><td>80790</td><td>41.8858007</td><td>0.3685293</td></tr><tr><td>Cabanyes, les</td><td>39.2908201 -0.5698989</td><td>80272</td><td>39.2908201</td><td>-0.5698989</td></tr><tr><td>Sant Martí Sarroca</td><td>41.3854214 1.6108158</td><td>82270</td><td>41.3854214</td><td>1.6108158</td></tr><tr><td>Siurana</td><td>42.2094291 3.0061564</td><td>170524</td><td>42.2094291</td><td>3.0061564</td></tr><tr><td>Nou de Gaià, la</td><td>41.1822282 1.3738261</td><td>430976</td><td>41.1822282</td><td>1.3738261</td></tr><tr><td>Malla</td><td>41.887016 2.2354564</td><td>81115</td><td>41.887016</td><td>2.2354564</td></tr><tr><td>Selva de Mar, la</td><td>41.4080147 2.2091094</td><td>171886</td><td>41.4080147</td><td>2.2091094</td></tr><tr><td>Móra d'Ebre</td><td>41.0893373 0.6412887</td><td>430939</td><td>41.0893373</td><td>0.6412887</td></tr><tr><td>Agullana</td><td>42.3938409 2.8469168</td><td>170010</td><td>42.3938409</td><td>2.8469168</td></tr><tr><td>Pobla de Segur, la</td><td>42.2473665 0.9672725</td><td>251713</td><td>42.2473665</td><td>0.9672725</td></tr><tr><td>Arenys de Mar</td><td>41.5797031 2.5491562</td><td>80060</td><td>41.5797031</td><td>2.5491562</td></tr><tr><td>Badalona</td><td>41.4493539 2.248254</td><td>80155</td><td>41.4493539</td><td>2.248254</td></tr><tr><td>Vilalba dels Arcs</td><td>41.1203999 0.4097144</td><td>431750</td><td>41.1203999</td><td>0.4097144</td></tr><tr><td>Prat de Comte</td><td>40.9829428 0.4057612</td><td>431172</td><td>40.9829428</td><td>0.4057612</td></tr><tr><td>Clariana de Cardener</td><td>41.9337762 1.6255629</td><td>250753</td><td>41.9337762</td><td>1.6255629</td></tr><tr><td>Sort</td><td>42.4114509 1.1298362</td><td>252094</td><td>42.4114509</td><td>1.1298362</td></tr><tr><td>Mediona</td><td>41.47739425 1.635018453270908</td><td>81228</td><td>41.47739425</td><td>1.635018453270908</td></tr><tr><td>Verdú</td><td>41.6102775 1.143512</td><td>252424</td><td>41.6102775</td><td>1.143512</td></tr><tr><td>Coma i la Pedra, la</td><td>42.17449855 1.5817023533792938</td><td>251636</td><td>42.17449855</td><td>1.5817023533792938</td></tr><tr><td>Prats de Lluçanès</td><td>42.0085421 2.0298689</td><td>81712</td><td>42.0085421</td><td>2.0298689</td></tr><tr><td>Masies de Voltregà, les</td><td>42.0267288 2.2347147</td><td>81173</td><td>42.0267288</td><td>2.2347147</td></tr><tr><td>Palma d'Ebre, la</td><td>41.2833974 0.6656065</td><td>430995</td><td>41.2833974</td><td>0.6656065</td></tr><tr><td>Bell-lloc d'Urgell</td><td>41.6321157 0.7769267</td><td>250485</td><td>41.6321157</td><td>0.7769267</td></tr><tr><td>Santa Eugènia de Berga</td><td>41.9000058 2.283319</td><td>82460</td><td>41.9000058</td><td>2.283319</td></tr><tr><td>Estaràs</td><td>41.6918459 1.3781492</td><td>250851</td><td>41.6918459</td><td>1.3781492</td></tr><tr><td>Torre de Fontaubella, la</td><td>41.1247206 0.8656245</td><td>431515</td><td>41.1247206</td><td>0.8656245</td></tr><tr><td>Castelló de Farfanya</td><td>41.8195348 0.7284574</td><td>250693</td><td>41.8195348</td><td>0.7284574</td></tr><tr><td>Sant Llorenç d'Hortons</td><td>41.4681755 1.8253181</td><td>82227</td><td>41.4681755</td><td>1.8253181</td></tr><tr><td>Vilafranca del Penedès</td><td>41.3463825 1.6995213</td><td>83054</td><td>41.3463825</td><td ...

# %%
# Se ejecuta una crossjoin para tener todas la posibilidades de estaciones y
#municipios con el fin de calcular la distancia entre todos ellos y finalmente obtener la estacion más cercana

munic_estaciones_convinations = missing_muniDF.crossJoin(estacionesDF)
munic_estaciones_convinations.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 198660</div>

# %%
from geopy.distance import geodesic
from pyspark.sql.types import FloatType

@F.udf(returnType=FloatType())
def geodesic_udf(a, b):
    """
    Funcion para calcular la distancia entre dos puntos de coordinadas
    """
    return geodesic(a, b).m

estacion_munic_distancia = munic_estaciones_convinations.withColumn('estacion_muni_distancia_m', geodesic_udf(F.array("municipio_lat", "municipio_lon"), F.array("latitud", "longitud")))
display(estacion_munic_distancia)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>municipio</th><th>location_code</th><th>codigo_municipio</th><th>municipio_lat</th><th>municipio_lon</th><th>indicativo</th><th>latitud</th><th>longitud</th><th>nombre</th><th>estacion_muni_distancia_m</th></tr></thead><tbody><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>X4</td><td>41.3839</td><td>2.16775</td><td>Barcelona</td><td>75321.96</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>YG</td><td>42.51881</td><td>1.24244</td><td>Tírvia</td><td>114870.95</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>VY</td><td>41.25095</td><td>1.29863</td><td>Nulles</td><td>129723.266</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>YD</td><td>41.51135</td><td>0.85617</td><td>Les Borges Blanques</td><td>145431.02</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>VD</td><td>41.68939</td><td>1.20381</td><td>Els Plans de Sió</td><td>111165.33</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>WX</td><td>41.9178</td><td>0.88175</td><td>Camarasa</td><td>131795.7</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>XV</td><td>41.48311</td><td>2.07956</td><td>Sant Cugat del Vallès</td><td>68141.54</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>U1</td><td>42.30648</td><td>2.95481</td><td>Cabanes</td><td>51164.848</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>CY</td><td>41.87813</td><td>2.17873</td><td>Muntanyola</td><td>28786.14</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>D6</td><td>42.43515</td><td>3.16622</td><td>Portbou</td><td>73684.72</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>D3</td><td>41.38197</td><td>1.93564</td><td>Vallirana</td><td>83871.35</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>Z1</td><td>42.64691</td><td>0.98486</td><td>Alt Àneu</td><td>140248.5</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>X1</td><td>41.15374</td><td>0.81953</td><td>Falset</td><td>167872.23</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>VH</td><td>41.65814</td><td>0.39301</td><td>Gimenells i el Pla de la Font</td><td>176859.81</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>WK</td><td>41.81949</td><td>0.57768</td><td>Alfarràs</td><td>158230.34</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>YL</td><td>41.1227</td><td>0.96951</td><td>Riudecanyes</td><td>159973.03</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>CT</td><td>42.39811</td><td>0.74362</td><td>El Pont de Suert</td><td>148112.2</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>XR</td><td>41.31481</td><td>0.98161</td><td>Prades</td><td>146553.0</td></tr><tr><td>Rupit i Pruit</td><td>42.024334 2.4653919</td><td>89019</td><td>42.024334</td><td>2.4653919</td><td>H1</td><td>41.58642</td><td>1.65306</td><td>Òdena</td><td>83203.54</td></tr><tr><td>Rupit i Pruit</td><td>42.024334  ...

# %%
#Calculamos un ranking de estaciones mas cercanas a mas lejanas
# La estacion con row_number igual a 1 sera la mas cercana
windowSpec  = Window.partitionBy("municipio").orderBy("estacion_muni_distancia_m")

estacion_munic_distancia=estacion_munic_distancia.withColumn("row_number",row_number().over(windowSpec))
display(estacion_munic_distancia)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>municipio</th><th>location_code</th><th>codigo_municipio</th><th>municipio_lat</th><th>municipio_lon</th><th>indicativo</th><th>latitud</th><th>longitud</th><th>nombre</th><th>estacion_muni_distancia_m</th><th>row_number</th></tr></thead><tbody><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>XC</td><td>41.47892</td><td>1.97546</td><td>Castellbisbal</td><td>7646.6675</td><td>1</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>CE</td><td>41.53109</td><td>1.80813</td><td>Els Hostalets de Pierola</td><td>7957.4097</td><td>2</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>D2</td><td>41.59252</td><td>1.915</td><td>Vacarisses</td><td>8073.4136</td><td>3</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>YK</td><td>41.55361</td><td>1.99005</td><td>Terrassa</td><td>8188.393</td><td>4</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>WN</td><td>41.59539</td><td>1.83751</td><td>Monistrol de Montserrat</td><td>9929.583</td><td>5</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>VU</td><td>41.63286</td><td>1.91718</td><td>Rellinars</td><td>12545.819</td><td>6</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>WY</td><td>41.43386</td><td>1.79429</td><td>Sant Sadurní d'Anoia</td><td>13192.308</td><td>7</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>XF</td><td>41.56568</td><td>2.06952</td><td>Sabadell</td><td>14821.011</td><td>8</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>XV</td><td>41.48311</td><td>2.07956</td><td>Sant Cugat del Vallès</td><td>15361.012</td><td>9</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>D3</td><td>41.38197</td><td>1.93564</td><td>Vallirana</td><td>15628.157</td><td>10</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>0229I</td><td>41.52361111111111</td><td>2.1030555555555557</td><td>SABADELL AEROPUERTO</td><td>16750.924</td><td>11</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>WP</td><td>41.48518</td><td>1.69337</td><td>Mediona</td><td>17887.592</td><td>12</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>CL</td><td>41.67399</td><td>1.76796</td><td>Sant Salvador de Guardiola</td><td>20407.6</td><td>13</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>VV</td><td>41.68129</td><td>2.02647</td><td>Sant Llorenç Savall</td><td>20641.957</td><td>14</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>R1</td><td>41.70637</td><td>1.87276</td><td>El Pont de Vilomara i Rocafort</td><td>20797.133</td><td>15</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>D5</td><td>41.41843</td><td>2.12388</td><td>Barcelona</td><td>21694.186</td><td>16</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>0200E</td><td>41.41833333333333</td><td>2.1241666666666665</td><td>BARCELONA, FABRA</td><td>21720.227</td><td>17</td></tr><tr><td>Abrera</td><td>41.5204464 1.9024126</td><td>80018</td><td>41.5204464</td><td>1.9024126</td><td>H1</td><td>41.58642</td><td>1.65306</td><td>Òdena</td><td>22055.578</ ...

# %%
estacion_munic_distancia= estacion_munic_distancia.filter(F.col("row_number")=="1").select(["codigo_municipio","municipio","indicativo","nombre","row_number"]).withColumnRenamed("nombre","nombre_estacion")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(estacion_munic_distancia)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>codigo_municipio</th><th>municipio</th><th>indicativo</th><th>nombre_estacion</th><th>row_number</th></tr></thead><tbody><tr><td>80018</td><td>Abrera</td><td>XC</td><td>Castellbisbal</td><td>1</td></tr><tr><td>250045</td><td>Alamús, els</td><td>XM</td><td>Els Alamús</td><td>1</td></tr><tr><td>170046</td><td>Albons</td><td>UB</td><td>La Tallada d'Empordà</td><td>1</td></tr><tr><td>430081</td><td>Alfara de Carles</td><td>U7</td><td>Aldover</td><td>1</td></tr><tr><td>430094</td><td>Alforja</td><td>MR</td><td>Cornudella de Montsant</td><td>1</td></tr><tr><td>250143</td><td>Alfés</td><td>X7</td><td>Torres de Segre</td><td>1</td></tr><tr><td>250169</td><td>Alguaire</td><td>X3</td><td>Alguaire</td><td>1</td></tr><tr><td>250215</td><td>Almenar</td><td>WK</td><td>Alfarràs</td><td>1</td></tr><tr><td>250241</td><td>Alt Àneu</td><td>Z1</td><td>Alt Àneu</td><td>1</td></tr><tr><td>430136</td><td>Ametlla de Mar, l'</td><td>UA</td><td>L'Ametlla de Mar</td><td>1</td></tr><tr><td>430141</td><td>Amposta</td><td>UU</td><td>Amposta</td><td>1</td></tr><tr><td>170097</td><td>Arbúcies</td><td>XK</td><td>Fogars de Montclús</td><td>1</td></tr><tr><td>80076</td><td>Arenys de Munt</td><td>0252D</td><td>ARENYS DE MAR</td><td>1</td></tr><tr><td>80095</td><td>Argentona</td><td>UP</td><td>Cabrils</td><td>1</td></tr><tr><td>80082</td><td>Argençola</td><td>XA</td><td>Montmaneu</td><td>1</td></tr><tr><td>430189</td><td>Arnes</td><td>D8</td><td>Horta de Sant Joan</td><td>1</td></tr><tr><td>250313</td><td>Arres</td><td>Z6</td><td>Arres</td><td>1</td></tr><tr><td>250328</td><td>Arsèguel</td><td>9619</td><td>LA SEU D'URGELL</td><td>1</td></tr><tr><td>250371</td><td>Avellanes i Santa Linya, les</td><td>UY</td><td>Os de Balaguer</td><td>1</td></tr><tr><td>80137</td><td>Avinyonet del Penedès</td><td>W4</td><td>La Granada</td><td>1</td></tr><tr><td>250404</td><td>Balaguer</td><td>V1</td><td>Vallfogona de Balaguer</td><td>1</td></tr><tr><td>80207</td><td>Begues</td><td>UF</td><td>Begues</td><td>1</td></tr><tr><td>170139</td><td>Begur</td><td>UE</td><td>Torroella de Montgrí</td><td>1</td></tr><tr><td>250463</td><td>Belianes</td><td>WL</td><td>Sant Martí de Riucorb</td><td>1</td></tr><tr><td>250485</td><td>Bell-lloc d'Urgell</td><td>XM</td><td>Els Alamús</td><td>1</td></tr><tr><td>250479</td><td>Bellcaire d'Urgell</td><td>V1</td><td>Vallfogona de Balaguer</td><td>1</td></tr><tr><td>80214</td><td>Bellprat</td><td>UJ</td><td>Santa Coloma de Queralt</td><td>1</td></tr><tr><td>430249</td><td>Bellvei</td><td>D9</td><td>El Vendrell</td><td>1</td></tr><tr><td>170216</td><td>Beuda</td><td>Y5</td><td>Navata</td><td>1</td></tr><tr><td>430271</td><td>Bisbal de Falset, la</td><td>D1</td><td>Margalef</td><td>1</td></tr><tr><td>430290</td><td>Blancafort</td><td>W8</td><td>Blancafort</td><td>1</td></tr><tr><td>170237</td><td>Blanes</td><td>WT</td><td>Malgrat de Mar</td><td>1</td></tr><tr><td>170293</td><td>Boadella i les Escaules</td><td>J5</td><td>Darnius</td><td>1</td></tr><tr><td>250582</td><td>Borges Blanques, les</td><td>YD</td><td>Les Borges Blanques</td><td>1</td></tr><tr><td>430311</td><td>Borges del Camp, les</td><td>YL</td><td>Riudecanyes</td><td>1</td></tr><tr><td>170268</td><td>Borrassà</td><td>Y5</td><td>Navata</td><td>1</td></tr><tr><td>250595</td><td>Bossòst</td><td>Z6</td><td>Arres</td><td>1</td></tr><tr><td>430332</td><td>Botarell</td><td>YL</td><td>Riudecanyes</td><td>1</td></tr><tr><td>170280</td><td>Brunyola i Sant Martí Sapresa</td><td>XS</td><td>Santa Coloma de Farners</td><td>1</td></tr><tr><td>430363</td><td>Cabra del Camp</td><td>W8</td><td>Blancafort</td><td>1</td></tr><tr><td>80288</td><td>Cabrera d'Anoia</td><td>WP</td><td>Mediona</td><td>1</td></tr><tr><td>80305</td><td>Cabrils</td><td>UP</td><td>Cabrils</td><td>1</td></tr><tr><td>170329</td><td>Cadaqués</td><td>D4</td><td>Roses</td><td>1</td></tr><tr><td>80312</td><td>Calaf</td><td>YH</td>< ...

# %%
estacion_munic_distancia.write.mode("overwrite").parquet(f"/mnt/IncendiosForestalesCAT/prep/meteocat/estaciones_cercanas_municipio/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
